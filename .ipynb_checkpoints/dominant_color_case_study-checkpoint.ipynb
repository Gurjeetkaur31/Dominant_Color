# %%
# for image recogonition 
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
image = cv2.imread('image.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image.shape
# Out:
# (960L, 1440L, 3L)

# %%
plt.figure()
plt.axis("off")
plt.imshow(image)

# %%
image.shape
# Out:
# (960L, 1440L, 3L)

# %%
plt.figure()
plt.axis("on")
plt.imshow(image)

# %%
image = image.reshape((image.shape[0] * image.shape[1], 3))
print image
print image.shape
# Out:
# [[ 71  75  86]
#  [ 71  75  86]
#  [ 72  76  87]
#  ...,
#  [108  80  66]
#  [107  79  65]
#  [107  79  65]]
# (1382400L, 3L)

# %%
from sklearn.cluster import KMeans
K = 3
clf = KMeans(n_clusters=K)
clf.fit(image)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#initialising the label dictionary
label = [0, 0, 0]

#finding count of data in each cluster
for x in clf.labels_:
    label[x] += 1

#Total Number of data points
label_sum = image.shape[0]

#converting to percentage
label = [float(x) / label_sum for x in label]
print label
# Out:
# [0.21014756944444443, 0.40660083912037037, 0.38325159143518517]

# %%
import webcolors

centroids = [x.astype("uint8").tolist() for x in clf.cluster_centers_]

clr = [webcolors.rgb_to_hex(c) for c in centroids]

plt.pie(label, colors=clr, shadow=True) 
plt.axis('equal')
plt.show()

# %%
import pandas as pd

# %%
# data frame for dominant color in each image
pine = pd.DataFrame({
    'Image name': [],
    'Dominant colour percentage': [],
    'Color': []
})

# %%
# to store dominant color realated data
data = []
# fetching images using the loop
for i in range(1,11):
    
    print '******^^^^^^^^^^^^^^ Image %s  ^^^^^^^^^^^^^^******' %i
    print '                     ________                      '
    
    
    
    # reading a image
    image = cv2.imread('image.jpg')
    
    # covert image pixel values from BGR to RBG
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # to display width x height x channel
    print 'Image shape: '+str(image.shape)
    
    '''
    # to display image
    plt.figure(i)
    # setting image axis
    plt.axis("off")
    # displaying image
    plt.imshow(image)
    '''
    
    # converting 3d image array to 1d
    image = image.reshape((image.shape[0]*image.shape[1],3))
    # print image
    print 'Shape of image after image reshape: '+str(image.shape)

    # declaring object of KMeans
    kmeans = KMeans(n_clusters=3, random_state=0).fit(image)

    # initialising the label dictionary
    label = [0,0,0]

    # finding count of data in each cluster
    for x in kmeans.labels_:
        label[x] += 1

    # total number of data points
    label_sum = image.shape[0]

    #converting to percentage
    label = [round((float(x)/label_sum)*100, 2) for x in label]
    m = max(label)
    y = label.index(m)
    print 'Percentage of different colours: '+str(label)

    # print kmeans.cluster_centers_

    # color values of each centeroid pixels of different clusters
    centroids = [x.astype('uint8').tolist() for x in kmeans.cluster_centers_]
    print centroids
    
    # covert pixel RGB color intensity values to hex code
    clr = [webcolors.rgb_to_hex(c) for c in centroids]
    print 'colours hex codes: '+ str(clr)
    dc = clr[y]

    # ploting pie chart
    plt.pie(label, colors=clr, shadow=True, autopct='%1.1f%%')
    plt.axis('equal')
    plt.show()
    
    # appending data to list
    l = []
    l.append('Image'+str(i))
    l.append(m)
    l.append(dc)
    
    # appending list all the image details to a list
    data.append(l)
    
    # appending data to dataframe
    pine = pine.append(pd.DataFrame({
        'Image name' : [data[i-1][0]],
        'Dominant colour percentage' : [data[i-1][1]],
        'Color' : [data[i-1][2]]
    }))
# Out:
# ******^^^^^^^^^^^^^^ Image 1  ^^^^^^^^^^^^^^******
#                      ________
# Image shape: (960L, 1440L, 3L)
# Shape of image after image reshape: (1382400L, 3L)
# Percentage of different colours: [40.63, 21.02, 38.35]
# [[215, 185, 152], [101, 146, 186], [147, 108, 82]]
# colours hex codes: [u'#d7b998', u'#6592ba', u'#936c52']
# ******^^^^^^^^^^^^^^ Image 2  ^^^^^^^^^^^^^^******
#                      ________
# Image shape: (960L, 1440L, 3L)
# Shape of image after image reshape: (1382400L, 3L)
# Percentage of different colours: [40.63, 21.02, 38.35]
# [[215, 185, 152], [101, 146, 186], [147, 108, 82]]
# colours hex codes: [u'#d7b998', u'#6592ba', u'#936c52']
# ******^^^^^^^^^^^^^^ Image 3  ^^^^^^^^^^^^^^******
#                      ________
# Image shape: (960L, 1440L, 3L)
# Shape of image after image reshape: (1382400L, 3L)
# Percentage of different colours: [40.63, 21.02, 38.35]
# [[215, 185, 152], [101, 146, 186], [147, 108, 82]]
# colours hex codes: [u'#d7b998', u'#6592ba', u'#936c52']
# ******^^^^^^^^^^^^^^ Image 4  ^^^^^^^^^^^^^^******
#                      ________
# Image shape: (960L, 1440L, 3L)
# Shape of image after image reshape: (1382400L, 3L)
# Percentage of different colours: [40.63, 21.02, 38.35]
# [[215, 185, 152], [101, 146, 186], [147, 108, 82]]
# colours hex codes: [u'#d7b998', u'#6592ba', u'#936c52']
# ******^^^^^^^^^^^^^^ Image 5  ^^^^^^^^^^^^^^******
#                      ________
# Image shape: (960L, 1440L, 3L)
# Shape of image after image reshape: (1382400L, 3L)
# Percentage of different colours: [40.63, 21.02, 38.35]
# [[215, 185, 152], [101, 146, 186], [147, 108, 82]]
# colours hex codes: [u'#d7b998', u'#6592ba', u'#936c52']
# ******^^^^^^^^^^^^^^ Image 6  ^^^^^^^^^^^^^^******
#                      ________
# Image shape: (960L, 1440L, 3L)
# Shape of image after image reshape: (1382400L, 3L)
# Percentage of different colours: [40.63, 21.02, 38.35]
# [[215, 185, 152], [101, 146, 186], [147, 108, 82]]
# colours hex codes: [u'#d7b998', u'#6592ba', u'#936c52']
# ******^^^^^^^^^^^^^^ Image 7  ^^^^^^^^^^^^^^******
#                      ________
# Image shape: (960L, 1440L, 3L)
# Shape of image after image reshape: (1382400L, 3L)
# Percentage of different colours: [40.63, 21.02, 38.35]
# [[215, 185, 152], [101, 146, 186], [147, 108, 82]]
# colours hex codes: [u'#d7b998', u'#6592ba', u'#936c52']
# ******^^^^^^^^^^^^^^ Image 8  ^^^^^^^^^^^^^^******
#                      ________
# Image shape: (960L, 1440L, 3L)
# Shape of image after image reshape: (1382400L, 3L)
# Percentage of different colours: [40.63, 21.02, 38.35]
# [[215, 185, 152], [101, 146, 186], [147, 108, 82]]
# colours hex codes: [u'#d7b998', u'#6592ba', u'#936c52']
# ******^^^^^^^^^^^^^^ Image 9  ^^^^^^^^^^^^^^******
#                      ________
# Image shape: (960L, 1440L, 3L)
# Shape of image after image reshape: (1382400L, 3L)
# Percentage of different colours: [40.63, 21.02, 38.35]
# [[215, 185, 152], [101, 146, 186], [147, 108, 82]]
# colours hex codes: [u'#d7b998', u'#6592ba', u'#936c52']
# ******^^^^^^^^^^^^^^ Image 10  ^^^^^^^^^^^^^^******
#                      ________
# Image shape: (960L, 1440L, 3L)
# Shape of image after image reshape: (1382400L, 3L)
# Percentage of different colours: [40.63, 21.02, 38.35]
# [[215, 185, 152], [101, 146, 186], [147, 108, 82]]
# colours hex codes: [u'#d7b998', u'#6592ba', u'#936c52']

# %%
pine
# Out:
#      Color  Dominant colour percentage Image name
# 0  #d7b998                       40.63     Image1
# 0  #d7b998                       40.63     Image2
# 0  #d7b998                       40.63     Image3
# 0  #d7b998                       40.63     Image4
# 0  #d7b998                       40.63     Image5
# 0  #d7b998                       40.63     Image6
# 0  #d7b998                       40.63     Image7
# 0  #d7b998                       40.63     Image8
# 0  #d7b998                       40.63     Image9
# 0  #d7b998                       40.63    Image10

# %%
# for image recogonition 
import cv2
# for dataframes
import pandas as pd
# to print graphs
import matplotlib.pyplot as plt
# perform numeric operations
import numpy as np
# to print graphs on the same window
# %matplotlib inline
# to make matplotlib coding easy
import seaborn as sns
# object of sns
sns.set()

# %%
# most dominant colour in each picture
sns.barplot(data=domc, x='Image name', y='Dominant colour percentage')
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
# list of average percentage of different colours found in all the 10 images
g_Color = [['Blue',20.84],['Black',11.5],['White',29.61],['Red',10.16],['Grey',18.47],['Green',1.41],
           ['Salmon',5.5],['Brown',2.45]]

# converting list of list to a dataframe to print graph
avg_graph = pd.DataFrame(g_Color,columns=['Color','Average'],dtype=float)
print avg_graph
# Out:
#     Color  Average
# 0    Blue    20.84
# 1   Black    11.50
# 2   White    29.61
# 3     Red    10.16
# 4    Grey    18.47
# 5   Green     1.41
# 6  Salmon     5.50
# 7   Brown     2.45

# %%
# plotting bar graph for frequent colours in different images vs their percentage in all the 10 images 
sns.barplot(x='Color',y='Average',data=avg_graph)
sns.despine()
